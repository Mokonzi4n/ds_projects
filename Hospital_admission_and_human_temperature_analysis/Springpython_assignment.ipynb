# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np_data = np.random.randn(10,20)
randata = pd.DataFrame(np_data)

randata

plt.plot(np_data)
plt.show()
